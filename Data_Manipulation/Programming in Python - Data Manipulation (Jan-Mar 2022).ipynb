# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Swastik\\Desktop\\Dono Consulting\\Data Manipulation with Pandas\\For Class'

# %%
os.chdir('C:\\Users\\Swastik\\Desktop\\Dono Consulting\\Data Manipulation with Pandas\\For Class')

# %%
data = pd.read_csv('Store.csv',sep=',',header=0,encoding='latin')

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.shape
# Out:
# (9994, 21)

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data['City'].unique().tolist()
# Out:
# ['Henderson',
#  'Los Angeles',
#  'Fort Lauderdale',
#  'Concord',
#  'Seattle',
#  'Fort Worth',
#  'Madison',
#  'West Jordan',
#  'San Francisco',
#  'Fremont',
#  'Philadelphia',
#  'Orem',
#  'Houston',
#  'Richardson',
#  'Naperville',
#  'Melbourne',
#  'Eagan',
#  'Westland',
#  'Dover',
#  'New Albany',
#  'New York City',
#  'Troy',
#  'Chicago',
#  'Gilbert',
#  'Springfield',
#  'Jackson',
#  'Memphis',
#  'Decatur',
#  'Durham',
#  'Columbia',
#  'Rochester',
#  'Minneapolis',
#  'Portland',
#  'Saint Paul',
#  'Aurora',
#  'Charlotte',
#  'Orland Park',
#  'Urbandale',
#  'Columbus',
#  'Bristol',
#  'Wilmington',
#  'Bloomington',
#  'Phoenix',
#  'Roseville',
#  'Independence',
#  'Pasadena',
#  'Newark',
#  'Franklin',
#  'Scottsdale',
#  'San Jose',
#  'Edmond',
#  'Carlsbad',
#  'San Antonio',
#  'Monroe',
#  'Fairfield',
#  'Grand Prairie',
#  'Redlands',
#  'Hamilton',
#  'Westfield',
#  'Akron',
#  'Denver',
#  'Dallas',
#  'Whittier',
#  'Saginaw',
# ...

# %%
len(data['City'].unique())
# Out:
# 531

# %%
data['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
# what is the total quantity sold in the east region -- Filtering

# %%
data[data['Region']=='East'].shape[0]
# Out:
# 2848

# %%
data.query("Region=='East'").shape[0]
# Out:
# 2848

# %%
data.query("Region=='East'")['Quantity']
# Out:
# 23       2
# 27       7
# 28       2
# 29       3
# 30       2
#         ..
# 9968     2
# 9969     7
# 9981     5
# 9984    10
# 9985     4
# Name: Quantity, Length: 2848, dtype: int64

# %%
data.query("Region=='East'")['Quantity'].sum()
# Out:
# 10618

# %%
#sorting

# %%
#what are the 5 most valuable customers in the south region by sales?

# %%
data.query("Region=='South'").sort_values('Sales',ascending=False).head()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2011-145317  3/18/2011  3/23/2011  Standard Class
# 8488    8489  CA-2013-158841   2/2/2013   2/4/2013    Second Class
# 683      684  US-2014-168116  11/5/2014  11/5/2014        Same Day
# 509      510  CA-2012-145352  3/16/2012  3/22/2012  Standard Class
# 4297    4298  CA-2014-129021  8/24/2014  8/27/2014    Second Class
#
#      Customer ID         Customer Name      Segment        Country  \
# 2697    SM-20320           Sean Miller  Home Office  United States
# 8488    SE-20110          Sanjit Engle     Consumer  United States
# 683     GT-14635        Grant Thornton    Corporate  United States
# 509     CM-12385  Christopher Martinez     Consumer  United States
# 4297    PO-18850       Patrick O'Brill     Consumer  United States
#
#               City  ... Postal Code  Region       Product ID         Category  \
# ...

# %%
data.query("Region=='South'").sort_values('Sales',ascending=False)['Customer ID'].head(10)
# Out:
# 2697    SM-20320
# 8488    SE-20110
# 683     GT-14635
# 509     CM-12385
# 4297    PO-18850
# 9639    JH-15985
# 3280    GM-14695
# 7583    KH-16690
# 4093    KW-16435
# 1454    MC-17425
# Name: Customer ID, dtype: object

# %%
data.query("Region=='East'").sort_values('Sales',ascending=False)['Customer ID'].head(10)
# Out:
# 2623    TA-21385
# 4190    HL-15040
# 4277    BS-11365
# 6425    CC-12370
# 6626    TB-21400
# 7666    DR-12940
# 6340    TS-21370
# 1085    KD-16270
# 1803    JA-15970
# 8204    KD-16495
# Name: Customer ID, dtype: object

# %%
data.query("Region=='East'").sort_values('Sales',ascending=False).head()['Customer ID']
# Out:
# 2623    TA-21385
# 4190    HL-15040
# 4277    BS-11365
# 6425    CC-12370
# 6626    TB-21400
# Name: Customer ID, dtype: object

# %%
# perform similar operations segments, product IDs, categories, sub-categories

# %%
data.query("Region=='East' | Region=='South' & Segment=='Corporate'").sort_values('Sales',ascending=False).head()['Customer ID']
# Out:
# 2623    TA-21385
# 4190    HL-15040
# 4277    BS-11365
# 6425    CC-12370
# 683     GT-14635
# Name: Customer ID, dtype: object

# %%
# groupby and aggregate

# %%
# what is the average quantity sold by region

# %%
data.groupby('Region',as_index=False).agg({'Quantity':np.mean})
# Out:
#     Region  Quantity
# 0  Central  3.779595
# 1     East  3.728230
# 2    South  3.832716
# 3     West  3.829535

# %%
# what is the total sales by categories?

# %%
data.groupby('Category',as_index=False).agg({'Sales':np.sum})
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
# multi-level column indexing

# %%
data.groupby('Category')[['Sales','Profit']].agg(['max','sum'])
# Out:
#                      Sales                 Profit
#                        max          sum       max          sum
# Category
# Furniture         4416.174  741999.7953  1013.127   18451.2728
# Office Supplies   9892.740  719047.0320  4946.370  122490.8008
# Technology       22638.480  836154.0330  8399.976  145454.9481

# %%
data.groupby('Category')[['Sales','Profit']].agg({'Sales':sum, 'Profit':max})
# Out:
#                        Sales    Profit
# Category
# Furniture        494122.0969  1013.127
# Office Supplies  375122.4440  4946.370
# Technology       605739.5920  8399.976

# %%
data.query("Region=='East'").groupby('Category', as_index=False)[['Sales','Profit']].agg({'Sales':sum, 'Profit':max})
# Out:
#           Category       Sales     Profit
# 0        Furniture  208291.204  1013.1270
# 1  Office Supplies  205516.055  1453.1238
# 2       Technology  264973.981  5039.9856

# %%
# what is the average discount by segment?

# %%
data.groupby('Segment', as_index=False).agg({'Discount': 'mean'})
# Out:
#        Segment  Discount
# 0     Consumer  0.158141
# 1    Corporate  0.158228
# 2  Home Office  0.147128

# %%
data.groupby('Segment', as_index=False).agg({'Discount': 'mean'}).rename(columns={'Discount':'Average Discount'})
# Out:
#        Segment  Average Discount
# 0     Consumer          0.158141
# 1    Corporate          0.158228
# 2  Home Office          0.147128

# %%
data.groupby('Segment', as_index=False).agg({'Discount': 'mean'}).rename(columns={'Discount':'Average Discount'}).sort_values('Average Discount',ascending=False)
# Out:
#        Segment  Average Discount
# 1    Corporate          0.158228
# 0     Consumer          0.158141
# 2  Home Office          0.147128

# %%
# which segment of customers are most profitable?

# %%
data.groupby('Segment', as_index=False).agg({'Profit': 'sum'}).rename(columns = {'Profit': 'Profit_Sum'}).\
sort_values('Profit_Sum', ascending=False)
# Out:
#        Segment   Profit_Sum
# 0     Consumer  134119.2092
# 1    Corporate   91979.1340
# 2  Home Office   60298.6785

# %%
data.groupby('Segment', as_index=False).agg({'Profit': 'mean'}).rename(columns = {'Profit': 'Profit_Avg'}).\
sort_values('Profit_Avg', ascending=False)
# Out:
#        Segment  Profit_Avg
# 2  Home Office   33.818664
# 1    Corporate   30.456667
# 0     Consumer   25.836873

# %%
# Top 5 States by total profit?

# %%
data.groupby('State', as_index=False).agg({'Profit': 'sum'}).rename(columns = {'Profit': 'Profit_Sum'}).\
sort_values('Profit_Sum', ascending=False).head(5)
# Out:
#          State  Profit_Sum
# 3   California  76381.3871
# 30    New York  74038.5486
# 45  Washington  33402.6517
# 20    Michigan  24463.1876
# 44    Virginia  18597.9504

# %%
# Adding new columns

# %%
data['Hi-Low'] = (data['Sales'])/(data['Sales'].mean())

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data['Cost'] = data['Sales'] - data['Profit']

# %%
#Apply

# %%
def get_sum(x):
    return np.sum(x)

# %%
data[['Sales','Quantity','Discount','Profit']].apply(get_sum, axis=0)
# Out:
# Sales       2.297201e+06
# Quantity    3.787300e+04
# Discount    1.561090e+03
# Profit      2.863970e+05
# dtype: float64

# %%
#map

# %%
profit_flag = (data['Profit'] > 5000).map({True:'Above 5000',False:'Below 5000'})

# %%
profit_flag.head()
# Out:
# 0    Below 5000
# 1    Below 5000
# 2    Below 5000
# 3    Below 5000
# 4    Below 5000
# Name: Profit, dtype: object

# %%
data.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# Hi-Low           float64
# Cost             float64
# dtype: object

# %%
# datetime

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
data['Duration'] = data['Ship Date'] - data['Order Date']

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data[data['Duration']>'5 days'].shape[0]
# Out:
# 1822

# %%
data[data['Duration']>'5 days'].shape[0]/data.shape[0]
# Out:
# 0.18230938563137883

# %%
data[data['Duration']>'5 days'].groupby('State').agg({'Category':np.size})
# Out:
#                       Category
# State
# Alabama                     13
# Arizona                     51
# Arkansas                    16
# California                 340
# Colorado                    29
# Connecticut                 15
# Delaware                    29
# District of Columbia         7
# Florida                     67
# Georgia                     35
# Idaho                        1
# Illinois                    84
# Indiana                     35
# Iowa                        11
# Kansas                       4
# Kentucky                    24
# Louisiana                    1
# Maine                        3
# Maryland                    17
# Massachusetts               14
# Michigan                    75
# Minnesota                   22
# Mississippi                 10
# Missouri                     7
# Montana                      3
# Nebraska                     3
# Nevada                      13
# New Hampshire                4
# New Jersey                  38
# ...
