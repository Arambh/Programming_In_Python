# %%
## data source: https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset
## This is a fictional dataset created by IBM Scientists. 
## EDA and Data Manipulation analysis around reasons for employee attrition

# %%
# !pip3 install seaborn==0.9.0

# %%
# import all the necessary libraries
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings("ignore")

# %%
# data = pd.read_csv('HR-Employee-Attrition.csv')

# %%
# data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
# data.shape
# Out:
# (1470, 35)

# %%
# data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
# data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
## using plt.subplots, plot the density plots of Age, Working Years, Years at Present Organization and Years in Current Role
## use sns.distplot

# %%
# fig,ax = plt.subplots(2,2, figsize=(10,10))               
# plt.suptitle("Understanding the distribution of various factors", fontsize=20)
# sns.distplot(data['Age'], ax = ax[0,0])  
# ax[0][0].set_title('Distribution of Age')
# sns.distplot(data['TotalWorkingYears'], ax = ax[0,1])  
# ax[0][1].set_title('Distribution of Total Working Years')
# sns.distplot(data['YearsAtCompany'], ax = ax[1,0])  
# ax[1][0].set_title('Distribution of Years at company')
# sns.distplot(data['YearsInCurrentRole'], ax = ax[1,1])  
# ax[1][1].set_title('Distribution of Years in Current Role')
# plt.show()

# %%
## Majority of the employees are in the age group of 35-40 years and have a total experience of around 8-10 years. 
## They have typically spent around 2-4 years at the current organization
## and 2-3 years in their current roles

# %%
## count of Attrition levels using countplot

# %%
# sns.countplot(data['Attrition'])
# plt.show()

# %%
## Above plot shows that around 250 people have left the organization while 
## they were able to retain around 1200 people.

# %%
## Does Promotion affect Attrition? - use sns.scatterplot to observe

# %%
# yearpromo_count=data['YearsSinceLastPromotion'].value_counts()
# yearpromo_count
# Out:
# 0     581
# 1     357
# 2     159
# 7      76
# 4      61
# 3      52
# 5      45
# 6      32
# 11     24
# 8      18
# 9      17
# 15     13
# 13     10
# 12     10
# 14      9
# 10      6
# Name: YearsSinceLastPromotion, dtype: int64

# %%
# sns.scatterplot(data.YearsSinceLastPromotion, yearpromo_count, hue=data.Attrition, s=100)
# plt.xlabel("YearsSinceLastPromotion")
# plt.ylabel("No of Associates");

# %%
## All the employees who attrited have got promotions in less than 1 year duration. 
## While employees who haven’t got promotions are still with the company. 
## It shows the pattern that employees maybe until they get a promotion and start looking for other opportunities
## Promotion does seem to impact attrition rate

# %%
## What is the relation between gender wise job satisfaction for all the employees?

# %%
# sns.boxplot(x=data["Gender"],y=data['JobSatisfaction'],hue=data['Attrition'])

# %%
## distribution of job satisfaction for those who stayed is same irrespective of gender
## Amongst those who left, women had lower job satisfaction levels

# %%
## Which department has seen the most attrition?

# %%
# data['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
# data.groupby('Department')['Attrition'].value_counts()
# Out:
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# Name: Attrition, dtype: int64

# %%
# data.query('Attrition=="Yes"').groupby('Department')['Attrition'].value_counts()
# Out:
# Department              Attrition
# Human Resources         Yes           12
# Research & Development  Yes          133
# Sales                   Yes           92
# Name: Attrition, dtype: int64

# %%
# data['Attrition_mapped'] = (data['Attrition'] == "Yes").map({True:1, False:0})

# %%
# data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#          ...         StandardHours StockOptionLevel  TotalWorkingYears  \
# ...

# %%
# P = data.query('Attrition_mapped==1').groupby('Department').agg({'Attrition_mapped':np.sum})
# P['Percentage'] = 100 * P['Attrition_mapped']  / P['Attrition_mapped'].sum()
# P
# Out:
#                         Attrition_mapped  Percentage
# Department
# Human Resources                       12    5.063291
# Research & Development               133   56.118143
# Sales                                 92   38.818565

# %%
## Research & Development department has the highest attrition rate

# %%
## Which Job Role has seen the most attrition?

# %%
# data['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
# P = data.query('Attrition_mapped==1').groupby('JobRole').agg({'Attrition_mapped':np.sum})
# P['Percentage'] = 100 * P['Attrition_mapped']  / P['Attrition_mapped'].sum()
# P.sort_values('Percentage', ascending=False)
# Out:
#                            Attrition_mapped  Percentage
# JobRole
# Laboratory Technician                    62   26.160338
# Sales Executive                          57   24.050633
# Research Scientist                       47   19.831224
# Sales Representative                     33   13.924051
# Human Resources                          12    5.063291
# Manufacturing Director                   10    4.219409
# Healthcare Representative                 9    3.797468
# Manager                                   5    2.109705
# Research Director                         2    0.843882

# %%
## lab Technician job role was the most impacted by attrition and has the highest attrition rate

# %%
## Does income parity across departments have an effect on attrition?

# %%
# data.groupby('Department').agg({'MonthlyIncome':np.mean})
# Out:
#                         MonthlyIncome
# Department
# Human Resources           6654.507937
# Research & Development    6281.252862
# Sales                     6959.172646

# %%
# P = data.query('Attrition_mapped==1').groupby('Department').agg({'Attrition_mapped':np.sum, 'MonthlyIncome':np.mean})
# P['Percentage'] = 100 * P['Attrition_mapped']  / P['Attrition_mapped'].sum()
# P
# Out:
#                         Attrition_mapped  MonthlyIncome  Percentage
# Department
# Human Resources                       12    3715.750000    5.063291
# Research & Development               133    4108.075188   56.118143
# Sales                                 92    5908.456522   38.818565

# %%
# P = data.query('Attrition_mapped==0').groupby('Department').agg({'Attrition_mapped':'count', 'MonthlyIncome':np.mean})
# P['Percentage'] = 100 * P['Attrition_mapped']  / P['Attrition_mapped'].sum()
# P
# Out:
#                         Attrition_mapped  MonthlyIncome  Percentage
# Department
# Human Resources                       51    7345.980392    4.136253
# Research & Development               828    6630.326087   67.153285
# Sales                                354    7232.240113   28.710462

# %%
## Employees within the same department who attrite have lesser monthly income compared to those who don't

# %%
## Gender v/s monthly income for both attrite and non-attrite employees

# %%
# P = data.query('Attrition_mapped==1').groupby('Gender').agg({'Attrition_mapped':'count', 'MonthlyIncome':np.mean})
# P['Percentage'] = 100 * P['Attrition_mapped']  / P['Attrition_mapped'].sum()
# P
# Out:
#         Attrition_mapped  MonthlyIncome  Percentage
# Gender
# Female                87    4769.735632   36.708861
# Male                 150    4797.160000   63.291139

# %%
# P = data.query('Attrition_mapped==0').groupby('Gender').agg({'Attrition_mapped':'count', 'MonthlyIncome':np.mean})
# P['Percentage'] = 100 * P['Attrition_mapped']  / P['Attrition_mapped'].sum()
# P
# Out:
#         Attrition_mapped  MonthlyIncome  Percentage
# Gender
# Female               501    7019.429142   40.632603
# Male                 732    6704.964481   59.367397
